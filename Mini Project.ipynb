# %% [markdown]
# # Assignment 8: Mini Project
#
# Adhvait Ananthan Srinath
#
# Poh Shi Qian

# %% [markdown]
# ## Loading in the data

# %% [markdown]
# ### Dataset Citation
#
#
# Hugging Face. (2024). CCDV PubMed Summarization Dataset. Retrieved from https://huggingface.co/datasets/ccdv/pubmed-summarization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/Colab Notebooks/project_data/train.txt'
file_path1 = '/content/drive/My Drive/Colab Notebooks/project_data/test.txt'
file_path2 = '/content/drive/My Drive/Colab Notebooks/project_data/val.txt'

# %%
# !pip install jsonlines
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.2.0)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0

# %%
import jsonlines
import pandas as pd

# Create an empty list to store the data
data = []

# Open the JSONL file and read its contents
with jsonlines.open(file_path) as reader:
    for obj in reader:
        data.append(obj)

df = pd.DataFrame(data)

df.head()
# Out:
#    article_id                                       article_text  \
# 0  PMC3872579  [a recent systematic analysis showed that in 2...
# 1  PMC3770628  [it occurs in more than 50% of patients and ma...
# 2  PMC5330001  [tardive dystonia ( td ) , a rarer side effect...
# 3  PMC4386667  [lepidoptera include agricultural pests that ,...
# 4  PMC4307954  [syncope is caused by transient diffuse cerebr...
#
#                                        abstract_text labels  \
# 0  [<S> background : the present study was carrie...   None
# 1  [<S> backgroundanemia in patients with cancer ...   None
# 2  [<S> tardive dystonia ( td ) is a serious side...   None
# 3  [<S> many lepidopteran insects are agricultura...   None
# 4  [<S> we present an unusual case of recurrent c...   None
#
#                                        section_names  \
# 0  [INTRODUCTION, MATERIALS AND METHODS, Particip...
# 1  [Introduction, Patients and methods, Study des...
# 2  [INTRODUCTION, CASE REPORT, DISCUSSION, Declar...
# 3  [1. Introduction, 2. Insect Immunity, 3. Signa...
# 4  [Introduction, Case report, Discussion, Confli...
#
#                                             sections
# 0  [[a recent systematic analysis showed that in ...
# 1  [[it occurs in more than 50% of patients and m...
# 2  [[tardive dystonia ( td ) , a rarer side effec...
# 3  [[lepidoptera include agricultural pests that ...
# 4  [[syncope is caused by transient diffuse cereb...

# %%
new_df = df[['article_text', 'abstract_text']].copy()

articleText = new_df.sample(n=50, random_state=42)

print(articleText)

articleText.info()
# Out:
#                                              article_text  \
# 32536   [long - term synaptic plasticity is thought to...
# 543     [californium-252 is an artificial element with...
# 46953   [ewing 's sarcoma is a malignant nonosteogenic...
# 3580    [conventional endodontic treatment has experie...
# 95214   [choroidal osteoma ( choroidal osseous chorist...
# 36084   [quantitative nuclear magnetic resonance ( qnm...
# 29915   [laparoscopic cholecystectomy ( lc ) , as comp...
# 95647   [compared to the adult population , blunt lary...
# 15315                                                  []
# 96640   [infection with herpes simplex virus ( a dna v...
# 91297   [its clinical manifestations are related to th...
# 94277   [universal vaccination against acute communica...
# 101396  [image fusion software can derive a fusion ima...
# 32677   [ziehl  neelsen ( zn ) method for acid - fast ...
# 94053   [decades of funding and research focused on co...
# 53336   [in 2006 , the nhs institute for innovation an...
# 90075   [deep pressure pain was measured with the algo...
# 66265   [while high - throughput sequencing and microa...
# 69133   [it involves the apparent coordination of a br...
# 17975   [patients were retrospectively identified from...
# 6667    [pulmonary tumor thrombotic microangiopathy ( ...
# 116402  [although approximately 90% of them pass spont...
# 70841   [chromosomal aberrations are found among 27% o...
# 77573   [there are different definitions for the narro...
# 34104   [the argus ii retinal prosthesis may improve v...
# 76778   [jamaica is a developing country in the caribb...
# 19218   [early ischemic changes ( eic ) on computed to...
# 110669  [a proper assessment is as important as approp...
# 86693   [stria vascularis and the spiral ganglion cell...
# 53151   [although there is considerable pharmacokineti...
# 11566   [experimental details of the synthesis and cha...
# 87251   [pain is the most common symptom of osteoarthr...
# 88539   [we report on a patient with situs inversus to...
# 53534   [the common causes of renin - dependent second...
# 118336  [aneurysmal bone cyst ( abc ) is the rare , be...
# 113335  [it was described by bloch in 1927 as nevoid e...
# 25001   [optimizing rehabilitation after total knee re...
# 51558   [, it has become clear that the pelvic floor i...
# 3137    [thus , vision loss is a major medical , econo...
# 31755   [measles is a common disease in children , and...
# 58071   [the efficacy and safety of nepeta menthoides ...
# 85540   [generalized gingival enlargement can have a v...
# 52589   [choristoma is defined as microscopically norm...
# 74046   [sjogren - larsson syndrome ( sls ) is a rare ...
# 53722   [zirconia - based ceramics , such as yttria - ...
# 23037   [pain is a protective mechanism which has adap...
# 70884   [a 39-year - old man ( weight 65 kg ; height 1...
# 66388   [macrophages are involved in many aspects of i...
# 113066  [public health physical activity guidelines ( ...
# 51251   [the electronic density structure of a \n surf...
#
#                                             abstract_text
# 32536   [<S> understanding the spatiotemporal organiza...
# 543     [<S> background : in neutron interaction with ...
# 46953   [<S> ewing 's sarcoma is the second most commo...
# 3580    [<S> the aim of the present roentgenographic i...
# 95214   [<S> choroidal osteoma is a rare , benign tumo...
# 36084   [<S> quantitative nuclear magnetic resonance (...
# 29915   [<S> pseudoaneurysm of hepatic artery is a rar...
# 95647   [<S> paediatric blunt laryngeal trauma is infr...
# 15315   [<S> lipopolysaccharide endotoxin is the only ...
# 96640   [<S> background : recurrent herpes labialis ( ...
# 91297   [<S> backgroundalbinism causes significant eye...
# 94277   [<S> introductionvaricella zoster virus ( vzv ...
# 101396  [<S> image fusion software can derive a fusion...
# 32677   [<S> background : microscopy detection of acid...
# 94053   [<S> purposeafter decades of research , aids c...
# 53336   [<S> \n background . </S>, <S> day - case lapa...
# 90075   [<S> backgroundin diabetic persons with painle...
# 66265   [<S> the onto - tools suite is composed of an ...
# 69133   [<S> self - organized criticality purports to ...
# 17975   [<S> objectiveto explore the relationship betw...
# 6667    [<S> pulmonary tumor thrombotic microangiopath...
# 116402  [<S> ingestion of foreign body is a serious pr...
# 70841   [<S> one of the most common and benign variant...
# 77573   [<S> implant rehabilitations in the posterior ...
# 34104   [<S> introductionthe argus ii retinal prosthes...
# 76778   [<S> background : globally , suicide is the th...
# 19218   [<S> background and purposewe developed a nove...
# 110669  [<S> [ purpose ] the purpose of this study was...
# 86693   [<S> objectiveto locate the organic cation tra...
# 53151   [<S> the advent of targeted therapies , combin...
# 11566   [<S> the 2-oxoglutarate ( 2og)-dependent jumon...
# 87251   [<S> current knowledge on pathogenesis of oste...
# 88539   [<S> introduction : we report on a patient wit...
# 53534   [<S> a 25-year - old korean woman was referred...
# 118336  [<S> aneurysmal bone cyst ( abc ) is benign va...
# 113335  [<S> melanoacanthoma is very rare variant of s...
# 25001   [<S> purposein total knee arthroplasty , tissu...
# 51558   [<S> objectivethe pelvic floor is an integrate...
# 3137    [<S> neurodegenerative eye diseases , such as ...
# 31755   [<S> introductionimmunogenicity assessment fig...
# 58071   [<S> background : the efficacy and safety of n...
# 85540   [<S> gingival enlargement , one of the manifes...
# 52589   [<S> heterotopic gastric mucosa tissue is also...
# 74046   [<S> sjogren - larsson syndrome ( sls ) is a r...
# 53722   [<S> purposethis study investigated the influe...
# 23037   [<S> many attempts have been made to increase ...
# 70884   [<S> this report describes a rare case of peri...
# 66388   [<S> besides their evident importance in host ...
# 113066  [<S> public health guidelines for physical act...
# 51251   [<S> elastic \n and inelastic close - coupling...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 32536 to 51251
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   article_text   50 non-null     object
#  1   abstract_text  50 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# ## Preprocessing the Text

# %% [markdown]
# We are going to preprocess the code to clean and prepare the text for the summarization task. The code performs several steps:
#
# 1. Lowercasing
# 2. Removing punctuation
# 3. Tokenization
# 4. Part-of-Speech Tagging (POS) - Assigns a grammitical tag to each token
# 5. Named Entity Recognition (NER) - To identify named entities such as person names, locations, and organizations
# 6. Removing Stopwords and Named Entities - Removes common stopwords and named entities to focus on meaninful words.
#
# This will help us to improve the quality of the model and remove the "noise" from the text data.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import string

# Download the NER model (if not already downloaded)
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text_with_ner(text_list):
    text = ' '.join(text_list)
    text = text.lower()
    text = ''.join([char for char in text if char not in string.punctuation])

    # Tokenize the text
    tokens = word_tokenize(text)

    # Perform part-of-speech tagging
    pos_tags = pos_tag(tokens)

    # Perform named entity recognition
    named_entities = nltk.ne_chunk(pos_tags)

    # Remove stopwords and named entities
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word, tag in pos_tags if word.lower() not in stop_words and tag != 'NE']

    # Join tokens back into a string
    preprocessed_text = ' '.join(filtered_tokens)

    return preprocessed_text
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Applying the preprocessing function to both 'article_text' and 'abstract_text' columns
articleText['preprocessed_article_text'] = articleText['article_text'].apply(preprocess_text_with_ner)
articleText['preprocessed_abstract_text'] = articleText['abstract_text'].apply(preprocess_text_with_ner)

print(articleText[['preprocessed_article_text', 'preprocessed_abstract_text']])
articleText.info()
# Out:
#                                 preprocessed_article_text  \
# 32536   long term synaptic plasticity thought represen...
# 543     californium252 artificial element half life 26...
# 46953   ewing sarcoma malignant nonosteogenic primary ...
# 3580    conventional endodontic treatment experienced ...
# 95214   choroidal osteoma choroidal osseous choristoma...
# 36084   quantitative nuclear magnetic resonance qnmr w...
# 29915   laparoscopic cholecystectomy lc compared open ...
# 95647   compared adult population blunt laryngotrachea...
# 15315
# 96640   infection herpes simplex virus dna virus preva...
# 91297   clinical manifestations related reduction abse...
# 94277   universal vaccination acute communicable disea...
# 101396  image fusion software derive fusion image sing...
# 32677   ziehl neelsen zn method acid fast bacilli afb ...
# 94053   decades funding research focused combatting sp...
# 53336   2006 nhs institute innovation improvement part...
# 90075   deep pressure pain measured algometer ii devic...
# 66265   high throughput sequencing microarray technolo...
# 69133   involves apparent coordination broad hierarchy...
# 17975   patients retrospectively identified single cen...
# 6667    pulmonary tumor thrombotic microangiopathy ptt...
# 116402  although approximately 90 pass spontaneously r...
# 70841   chromosomal aberrations found among 27 couples...
# 77573   different definitions narrow diameter implant ...
# 34104   argus ii retinal prosthesis may improve visual...
# 76778   jamaica developing country caribbean populatio...
# 19218   early ischemic changes eic computed tomography...
# 110669  proper assessment important appropriate treatm...
# 86693   stria vascularis spiral ganglion cells also re...
# 53151   although considerable pharmacokinetics experti...
# 11566   experimental details synthesis characterisatio...
# 87251   pain common symptom osteoarthritis oa pain lev...
# 88539   report patient situs inversus totalis underwen...
# 53534   common causes renin dependent secondary hypert...
# 118336  aneurysmal bone cyst abc rare benign vascular ...
# 113335  described bloch 1927 nevoid epithelioma type 1...
# 25001   optimizing rehabilitation total knee replaceme...
# 51558   become clear pelvic floor frozen functional un...
# 3137    thus vision loss major medical economic safety...
# 31755   measles common disease children responsible la...
# 58071   efficacy safety nepeta menthoides freeze dried...
# 85540   generalized gingival enlargement variety etiol...
# 52589   choristoma defined microscopically normal cell...
# 74046   sjogren larsson syndrome sls rare autosomal re...
# 53722   zirconia based ceramics yttria tetragonal zirc...
# 23037   pain protective mechanism adaptive value inabi...
# 70884   39year old man weight 65 kg height 168 cm sche...
# 66388   macrophages involved many aspects immunity add...
# 113066  public health physical activity guidelines pag...
# 51251   electronic density structure surface determine...
#
#                                preprocessed_abstract_text
# 32536   understanding spatiotemporal organization long...
# 543     background neutron interaction matter reductio...
# 46953   ewing sarcoma second common malignant primary ...
# 3580    aim present roentgenographic vitro study deter...
# 95214   choroidal osteoma rare benign tumor usually di...
# 36084   quantitative nuclear magnetic resonance qnmr p...
# 29915   pseudoaneurysm hepatic artery rare known compl...
# 95647   paediatric blunt laryngeal trauma infrequently...
# 15315   lipopolysaccharide endotoxin known bacterial p...
# 96640   background recurrent herpes labialis rhl one c...
# 91297   backgroundalbinism causes significant eye morb...
# 94277   introductionvaricella zoster virus vzv etiolog...
# 101396  image fusion software derive fusion image sing...
# 32677   background microscopy detection acid fast baci...
# 94053   purposeafter decades research aids continues m...
# 53336   background day case laparoscopic cholecystecto...
# 90075   backgroundin diabetic persons painless neuropa...
# 66265   onto tools suite composed annotation database ...
# 69133   self organized criticality purports build mult...
# 17975   objectiveto explore relationship inpatient dia...
# 6667    pulmonary tumor thrombotic microangiopathy ptt...
# 116402  ingestion foreign body serious problem commonl...
# 70841   one common benign variants normal human karyot...
# 77573   implant rehabilitations posterior jaw influenc...
# 34104   introductionthe argus ii retinal prosthesis ma...
# 76778   background globally suicide third leading caus...
# 19218   background purposewe developed novel method na...
# 110669  purpose purpose study analyze test retest reli...
# 86693   objectiveto locate organic cation transporter ...
# 53151   advent targeted therapies combined unsustainab...
# 11566   2oxoglutarate 2ogdependent jumonji c domain jm...
# 87251   current knowledge pathogenesis osteoarticular ...
# 88539   introduction report patient situs inversus tot...
# 53534   25year old korean woman referred uncontrolled ...
# 118336  aneurysmal bone cyst abc benign vascular lesio...
# 113335  melanoacanthoma rare variant seborrheic kerato...
# 25001   purposein total knee arthroplasty tissue spari...
# 51558   objectivethe pelvic floor integrated structure...
# 3137    neurodegenerative eye diseases glaucoma cause ...
# 31755   introductionimmunogenicity assessment figures ...
# 58071   background efficacy safety nepeta menthoides f...
# 85540   gingival enlargement one manifestations gingiv...
# 52589   heterotopic gastric mucosa tissue also called ...
# 74046   sjogren larsson syndrome sls rare autosomal re...
# 53722   purposethis study investigated influence surfa...
# 23037   many attempts made increase duration local ane...
# 70884   report describes rare case perioperative midaz...
# 66388   besides evident importance host defense macrop...
# 113066  public health guidelines physical activity pa ...
# 51251   elastic inelastic close coupling cc calculatio...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 32536 to 51251
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   article_text                50 non-null     object
#  1   abstract_text               50 non-null     object
#  2   preprocessed_article_text   50 non-null     object
#  3   preprocessed_abstract_text  50 non-null     object
# dtypes: object(4)
# memory usage: 2.0+ KB

# %% [markdown]
# Now, we are going to identify and remove certain articles with a word count less that 400.
#
# Rows with less text are filtered out to improve the summarization quality

# %%
# Calculate word count for each row in the 'preprocessed_article_text' column
articleText['word_count'] = articleText['preprocessed_article_text'].apply(lambda x: len(x.split()))

# Identify rows with word count less than 400 for 'preprocessed_article_text'
filtered_out_rows = articleText[articleText['word_count'] < 400]

# Filter out rows with word count less than 400 for 'preprocessed_article_text'
articleText = articleText[articleText['word_count'] >= 400]

# Drop the 'word_count' column as it's no longer needed
articleText = articleText.drop(columns=['word_count'])

# Display the first few rows of the filtered out DataFrame for examination
articleText.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 32536 to 51251
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   article_text                44 non-null     object
#  1   abstract_text               44 non-null     object
#  2   preprocessed_article_text   44 non-null     object
#  3   preprocessed_abstract_text  44 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
# Create a DataFrame with only 'preprocessed_article_text'
articleText_article = articleText[['preprocessed_article_text']].copy()

# Create a DataFrame with only 'preprocessed_abstract_text'
articleText_abstract = articleText[['preprocessed_abstract_text']].copy()

# Display information about the new DataFrames
print("DataFrame with preprocessed article text:")
print(articleText_article.info())

print("\nDataFrame with preprocessed abstract text:")
print(articleText_abstract.info())
# Out:
# DataFrame with preprocessed article text:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 32536 to 51251
# Data columns (total 1 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   preprocessed_article_text  44 non-null     object
# dtypes: object(1)
# memory usage: 704.0+ bytes
# None
#
# DataFrame with preprocessed abstract text:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 32536 to 51251
# Data columns (total 1 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   preprocessed_abstract_text  44 non-null     object
# dtypes: object(1)
# memory usage: 704.0+ bytes
# None

# %% [markdown]
# ## Summarizing the Articles

# %% [markdown]
# For the summarization process, we are utilizing the Hugging Face **'transformer'** library to generate summaries for text input. The function takes a piece of text as input, truncates it to fit within the maximum sequence length, and then uses the default summarization pipeline to generate a summary.

# %%
from transformers import pipeline

# Load the default summarization pipeline
summarization_pipeline = pipeline("summarization")

# Define a function to generate summaries
def generate_summary(text):
    # Truncate the text to fit within the maximum sequence length
    truncated_text = text[:1024]  # Assuming maximum sequence length of 1024

    # Generate summary using the pipeline
    summary = summarization_pipeline(truncated_text, max_length=120, min_length=30, do_sample=False)

    # Extract and return the summary text
    return summary[0]['summary_text']

# Apply the function to each row in the DataFrame
articleText_article['summary'] = articleText_article['preprocessed_article_text'].apply(generate_summary)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
summaryText = articleText_article[['summary']].copy()

summaryText.head()
summaryText.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 32536 to 51251
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   summary  44 non-null     object
# dtypes: object(1)
# memory usage: 704.0+ bytes

# %% [markdown]
# ## Calculating BERT Score

# %% [markdown]
# We chose BERTScore specifically for evaluating summaries in this context for its effectiveness in capturing semantic similarity, robustness across various text data, and ease of use. These qualities make it a suitable choice for assessing the quality of generated summaries relative to the reference abstracts.

# %%
# !pip install bert_score
# Out:
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.1.0+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.5.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.38.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.31.0)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2023.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
from bert_score import score

# Define system-generated summaries and reference summaries
system_summaries = summaryText['summary'].tolist()
reference_summaries = articleText_abstract['preprocessed_abstract_text'].tolist()

# Calculate BERTScore
P, R, F1 = score(system_summaries, reference_summaries, lang="en", verbose=True)

# Print BERTScore
print("Precision:", P.mean())
print("Recall:", R.mean())
print("F1 Score:", F1.mean())
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 195.28 seconds, 0.23 sentences/sec
# Precision: tensor(0.8295)
# Recall: tensor(0.7937)
# F1 Score: tensor(0.8110)

# %% [markdown]
# **Precision**: A precision of 0.8295 suggests that the generated summaries are concise and focused and contains mostly relevant content from the reference abstracts.
#
# **Recall**: The recall score of 0.7937 suggests that the summaries are comprehensive and include a significant portion of the key information present in the reference.
#
# **F1 Score**: The F1 Score of 0.8110 implies that our summaries strike a good balance between precision and recall, affirming their accuracy and informativeness.

# %% [markdown]
# ## Extracting and Comparing Keywords

# %% [markdown]
# We also intend on extracting and comparing keywords. We intend to do this as this serves as a crucial tool for assessing their quality and effectiveness.

# %%
from collections import Counter

# Function to extract keywords from summary text
def extract_keywords_from_summary(text):
    # Ensure text is converted to string
    text = str(text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove punctuation and stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word.lower() for word in tokens if word.isalnum() and word.lower() not in stop_words]

    # Calculate word frequency
    word_freq = Counter(filtered_tokens)

    # Get top keywords based on frequency
    top_keywords = word_freq.most_common(10)  # Extract top 5 keywords

    return [keyword for keyword, freq in top_keywords]

# Extract keywords from the first row of summaryText
summary_keywords = extract_keywords_from_summary(summaryText['summary'].iloc[0])

# Print out the keywords
print("Top 10 keywords from the summary:", summary_keywords)
# Out:
# Top 10 keywords from the summary: ['long', 'term', 'synaptic', 'distribution', 'plasticity', 'thought', 'represent', 'cellular', 'basis', 'learning']

# %%
# Function to extract keywords from abstract text
def extract_keywords_from_abstract(text):
    # Ensure text is converted to string
    text = str(text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove punctuation and stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word.lower() for word in tokens if word.isalnum() and word.lower() not in stop_words]

    # Calculate word frequency
    word_freq = Counter(filtered_tokens)

    # Get top keywords based on frequency
    top_keywords = word_freq.most_common(10)  # Extract top 5 keywords

    return [keyword for keyword, freq in top_keywords]

# Extract keywords from the first row of summaryText
abstract_keywords = extract_keywords_from_abstract(articleText_abstract['preprocessed_abstract_text'].iloc[0])

# Print out the keywords
print("Top 10 keywords from the abstract:", abstract_keywords)
# Out:
# Top 10 keywords from the abstract: ['imaging', 'vsd', 'regions', 'long', 'term', 'synaptic', 'ltp', 'ltd', 'excited', 'plasticity']

# %% [markdown]
# Now we intend to compare the keywords from the article text in our generated summaries and the abstract provided in the dataset for each article

# %%
# Function to calculate similarity based on percentage
def calculate_similarity_percentage(keyword_list1, keyword_list2, reference_text):
    set1 = set(keyword_list1)
    set2 = set(keyword_list2)
    reference_set = set(word_tokenize(reference_text.lower()))

    # Calculate the intersection of keywords in summary and abstract with the reference text
    intersection_summary = set1.intersection(reference_set)
    intersection_abstract = set2.intersection(reference_set)

    # Calculate the percentage of keywords from reference text in summary and abstract
    percentage_summary = len(intersection_summary) / len(reference_set) * 100
    percentage_abstract = len(intersection_abstract) / len(reference_set) * 100

    return percentage_summary, percentage_abstract

# Calculate similarity percentage between summary keywords and abstract keywords
article_text = articleText_article['preprocessed_article_text'].iloc[0]
percentage_summary, percentage_abstract = calculate_similarity_percentage(summary_keywords, abstract_keywords, article_text)

print("Percentage of reference article text keywords in summary:", percentage_summary)
print("Percentage of reference article text keywords in abstract:", percentage_abstract)
# Out:
# Percentage of reference article text keywords in summary: 0.8554319931565441
# Percentage of reference article text keywords in abstract: 0.7698887938408896

# %% [markdown]
# These results suggest that the generated summaries contain a slightly higher percentage of keywords from the reference article text compared to that of the abstract. The fact that summary is able to capture around 85.5% of the keywords indicates that it contains a significant portion of key information as well.
